# %% [markdown]
# <a href="https://colab.research.google.com/github/MominaGull/ML-Practice-Projects/blob/main/Accident_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing required libraries
import torch
from torchvision import transforms, utils
from torch.utils.data.dataset import Dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from sklearn import preprocessing

# %%
# Mounting google drive to import dataset
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AH78T6sqZmgu_XjwRmqT9w61ZxxfdmP6Il6WSO05u0A-ULYFs0YERA
# Mounted at /content/drive

# %%
# Method to get images from drive using image path and labels from csv file
class ExtractDataFromCsv(Dataset):
    def __init__(self, csv_path):
        """
        Reading image locations and labels from csv
        but reading images from files
        Args:
            csv_path (string): path to csv file
        Returns:
            Image as transformed tensor and label
        """
        # Transforms images to gray scale and in 28 by 28 dimensions     
        self.to_tensor =  transforms.Compose([transforms.Grayscale(num_output_channels=1),transforms.Resize([28,28]) ,transforms.ToTensor()])

        # Read the csv file
        self.data_info = pd.read_csv(csv_path, header=None)
        # First column contains the image paths
        self.image_arr = np.asarray(self.data_info.iloc[:, 0])
        # Third column is the labels
        self.label_arr = np.asarray(self.data_info.iloc[:, 2])
     
        # Calculate length of data in csv file
        self.data_len = len(self.data_info.index)

    # Function to get images and labels
    def __getitem__(self, index):
        # Get image name from the csv file
        single_image_name = self.image_arr[index]
        # Open image using path, folder name and image name
        img_as_img = Image.open('/content/drive/My Drive/vehicles/train/images/'  + single_image_name)

        # Apply tranformations on image stored in to_tensor
        img_as_tensor = self.to_tensor(img_as_img)
        # Get label of the image
        single_image_label = self.label_arr[index]

        return (img_as_tensor, single_image_label)

    # Fucntion to get length of data in csv file
    def __len__(self):
        return self.data_len

# %%
# Read training image locations from Csv - transformations are defined inside ExtractDataFromCsv class
train_set = ExtractDataFromCsv('/content/drive/My Drive/vehicles/train/train.csv')

# Passing extracted images and labels to pytoch dataloader with batch size of 150
trainset_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=150, shuffle=False)

# %%
# Creating CNN model
class Model(torch.nn.Module):
  #
  #Passing gray scale image. Input channel for first convulation layer should be one.
  #Two classes. Final output neurons should be 2.
  #
    def __init__(self):
        super(Model, self).__init__()
        self.conv_1 = torch.nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.conv_2 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.max_pool2d = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.linear_1 = torch.nn.Linear(7 * 7 * 64, 128)
        self.linear_2 = torch.nn.Linear(128, 2)
        self.dropout = torch.nn.Dropout(p=0.5)
        self.relu = torch.nn.ReLU()

    def forward(self, x):
        x = self.conv_1(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = self.conv_2(x)
        x = self.relu(x)
        x = self.max_pool2d(x)
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        pred = self.linear_2(x)

        return pred

# %%
# Calling the Model class to get an object of CNN model
model = Model()
# Using CrossEntropyLoss to calculate loss
criterion = torch.nn.CrossEntropyLoss()
# Using Adam Optimizing algorithm with learning rate of 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training model for 100 epochs
no_epochs = 100
train_loss = list()

# Looping over total number of epochs
for epoch in range(no_epochs):
    # Setting initial total training loss to zero
    total_train_loss = 0

    # Iterating over images and labels in train dataloader object
    for itr, (images, labels) in enumerate(trainset_loader):
        
      # Transforming labels to tensors
      labels = torch.tensor(labels, dtype=torch.long)

      # Setting gradients to zero
      optimizer.zero_grad()

      # Passing image to CNN model
      pred = model(images)

      # Calculating loss 
      loss = criterion(pred, labels)
      # Updating training loss variable according to loss calculated
      total_train_loss += loss.item()
       
      # Performing back propagation
      loss.backward()
      optimizer.step()
  
    # Calculating total training loss
    total_train_loss = total_train_loss / (itr + 1)
    train_loss.append(total_train_loss)
 
    # Printing number of completed epochs, total epochs and training loss
    print('\nEpoch: {}/{}, Training Loss: {:.8f},'.format(epoch + 1, no_epochs, total_train_loss))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Epoch: 1/100, Training Loss: 2.45704769,
#
# Epoch: 2/100, Training Loss: 0.67752889,
#
# Epoch: 3/100, Training Loss: 0.69301741,
#
# Epoch: 4/100, Training Loss: 0.69323463,
#
# Epoch: 5/100, Training Loss: 0.69317179,
#
# Epoch: 6/100, Training Loss: 0.69307300,
#
# Epoch: 7/100, Training Loss: 0.69306733,
#
# Epoch: 8/100, Training Loss: 0.69304054,
#
# Epoch: 9/100, Training Loss: 0.69301738,
#
# Epoch: 10/100, Training Loss: 0.69297167,
#
# Epoch: 11/100, Training Loss: 0.69295166,
#
# Epoch: 12/100, Training Loss: 0.69290478,
#
# Epoch: 13/100, Training Loss: 0.69295638,
#
# Epoch: 14/100, Training Loss: 0.69283739,
#
# Epoch: 15/100, Training Loss: 0.69285975,
#
# Epoch: 16/100, Training Loss: 0.69280791,
#
# Epoch: 17/100, Training Loss: 0.69279794,
#
# Epoch: 18/100, Training Loss: 0.69272490,
#
# Epoch: 19/100, Training Loss: 0.69266707,
#
# Epoch: 20/100, Training Loss: 0.69259818,
#
# Epoch: 21/100, Training Loss: 0.69257933,
#
# Epoch: 22/100, Training Loss: 0.69261953,
#
# Epoch: 23/100, Training Loss: 0.69259503,
#
# Epoch: 24/100, Training Loss: 0.69274853,
#
# Epoch: 25/100, Training Loss: 0.69243438,
#
# Epoch: 26/100, Training Loss: 0.69245502,
#
# Epoch: 27/100, Training Loss: 0.69213656,
#
# Epoch: 28/100, Training Loss: 0.69184847,
#
# Epoch: 29/100, Training Loss: 0.69185847,
#
# Epoch: 30/100, Training Loss: 0.69142389,
#
# Epoch: 31/100, Training Loss: 0.69172813,
#
# Epoch: 32/100, Training Loss: 0.69154428,
#
# Epoch: 33/100, Training Loss: 0.69204181,
#
# Epoch: 34/100, Training Loss: 0.69138596,
#
# Epoch: 35/100, Training Loss: 0.69077466,
#
# Epoch: 36/100, Training Loss: 0.68980289,
#
# Epoch: 37/100, Training Loss: 0.68906682,
#
# Epoch: 38/100, Training Loss: 0.69094928,
#
# Epoch: 39/100, Training Loss: 0.69039892,
#
# Epoch: 40/100, Training Loss: 0.69110573,
#
# Epoch: 41/100, Training Loss: 0.68678306,
#
# Epoch: 42/100, Training Loss: 0.68902028,
#
# Epoch: 43/100, Training Loss: 0.68780687,
#
# Epoch: 44/100, Training Loss: 0.69118693,
#
# Epoch: 45/100, Training Loss: 0.68702757,
#
# Epoch: 46/100, Training Loss: 0.68566235,
#
# Epoch: 47/100, Training Loss: 0.68437743,
#
# Epoch: 48/100, Training Loss: 0.68233140,
#
# Epoch: 49/100, Training Loss: 0.67807569,
#
# Epoch: 50/100, Training Loss: 0.67939599,
#
# Epoch: 51/100, Training Loss: 0.67263534,
#
# Epoch: 52/100, Training Loss: 0.67588038,
#
# Epoch: 53/100, Training Loss: 0.65818816,
#
# Epoch: 54/100, Training Loss: 0.65649333,
#
# Epoch: 55/100, Training Loss: 0.64282752,
#
# Epoch: 56/100, Training Loss: 0.64617392,
#
# Epoch: 57/100, Training Loss: 0.63816113,
#
# Epoch: 58/100, Training Loss: 0.64088035,
#
# Epoch: 59/100, Training Loss: 0.63488412,
#
# Epoch: 60/100, Training Loss: 0.63031654,
#
# Epoch: 61/100, Training Loss: 0.62600846,
#
# Epoch: 62/100, Training Loss: 0.60621757,
#
# Epoch: 63/100, Training Loss: 0.60682885,
#
# Epoch: 64/100, Training Loss: 0.59395168,
#
# Epoch: 65/100, Training Loss: 0.61750057,
#
# Epoch: 66/100, Training Loss: 0.59117898,
#
# Epoch: 67/100, Training Loss: 0.59114849,
#
# Epoch: 68/100, Training Loss: 0.59225234,
#
# Epoch: 69/100, Training Loss: 0.57656865,
#
# Epoch: 70/100, Training Loss: 0.57895955,
#
# Epoch: 71/100, Training Loss: 0.56872538,
#
# Epoch: 72/100, Training Loss: 0.56409016,
#
# Epoch: 73/100, Training Loss: 0.55272739,
#
# Epoch: 74/100, Training Loss: 0.55092291,
#
# Epoch: 75/100, Training Loss: 0.54766478,
#
# Epoch: 76/100, Training Loss: 0.54048979,
#
# Epoch: 77/100, Training Loss: 0.53471821,
#
# Epoch: 78/100, Training Loss: 0.51501365,
#
# Epoch: 79/100, Training Loss: 0.52901547,
#
# Epoch: 80/100, Training Loss: 0.51138032,
#
# Epoch: 81/100, Training Loss: 0.53155052,
#
# Epoch: 82/100, Training Loss: 0.50156556,
#
# Epoch: 83/100, Training Loss: 0.49960028,
#
# Epoch: 84/100, Training Loss: 0.49223249,
#
# Epoch: 85/100, Training Loss: 0.48062730,
#
# Epoch: 86/100, Training Loss: 0.48406104,
#
# Epoch: 87/100, Training Loss: 0.47472250,
#
# Epoch: 88/100, Training Loss: 0.48654677,
#
# Epoch: 89/100, Training Loss: 0.46656039,
#
# Epoch: 90/100, Training Loss: 0.47050437,
#
# Epoch: 91/100, Training Loss: 0.45331578,
#
# Epoch: 92/100, Training Loss: 0.46408239,
#
# Epoch: 93/100, Training Loss: 0.43666755,
#
# Epoch: 94/100, Training Loss: 0.46605920,
#
# Epoch: 95/100, Training Loss: 0.42593964,
#
# Epoch: 96/100, Training Loss: 0.43690171,
#
# Epoch: 97/100, Training Loss: 0.42556100,
#
# Epoch: 98/100, Training Loss: 0.43821964,
#
# Epoch: 99/100, Training Loss: 0.43280533,
#
# Epoch: 100/100, Training Loss: 0.43168737,

# %%
# Read validation image locations from Csv - transformations are defined inside ExtractDataFromCsv class
val_set = ExtractDataFromCsv('/content/drive/My Drive/vehicles/validation/validation.csv')

# Passing extracted images and labels to pytoch dataloader with batch size of 150
valset_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=150, shuffle=False)

# %%
# Validation model

results = list()
total = 0

# Iterating over images and labels in validation dataloader object
for itr, (image, label) in enumerate(valset_loader):
  
    # Passing image to model
    pred = model(image)
    # Predicting label for passed image
    pred = torch.nn.functional.softmax(pred, dim=1)

    # Looping over the predicted probabilities for both classes
    for i, p in enumerate(pred):

        # Printing predictions
        print("p.data:",p.data)
        # Printing actual labels
        print("label", label[i])

        # Condition to check if label is equal to prediction
        if label[i] == torch.max(p.data, 0)[1]:
            # Increment total by one if prediction is correct
            total = total + 1

            # Appending image and label in result list
            results.append((image, torch.max(p.data, 0)[1]))

# Calculating accuracy 
test_accuracy = total / (itr + 1)
# Printing accuaracy of model on validation set
print('Test accuracy {:.8f}'.format(test_accuracy))
# Out:
# p.data: tensor([0.5283, 0.4717])
# label tensor(0)
# p.data: tensor([0.7494, 0.2506])
# label tensor(0)
# p.data: tensor([0.7370, 0.2630])
# label tensor(0)
# p.data: tensor([0.5720, 0.4280])
# label tensor(0)
# p.data: tensor([0.5721, 0.4279])
# label tensor(0)
# p.data: tensor([0.8259, 0.1741])
# label tensor(0)
# p.data: tensor([0.9431, 0.0569])
# label tensor(0)
# p.data: tensor([0.9102, 0.0898])
# label tensor(0)
# p.data: tensor([0.6883, 0.3117])
# label tensor(0)
# p.data: tensor([0.8410, 0.1590])
# label tensor(0)
# p.data: tensor([0.8212, 0.1788])
# label tensor(0)
# p.data: tensor([0.5033, 0.4967])
# label tensor(0)
# p.data: tensor([0.8822, 0.1178])
# label tensor(0)
# p.data: tensor([0.3598, 0.6402])
# label tensor(0)
# p.data: tensor([0.6639, 0.3361])
# label tensor(0)
# p.data: tensor([0.9221, 0.0779])
# label tensor(0)
# p.data: tensor([0.8384, 0.1616])
# label tensor(0)
# p.data: tensor([0.6969, 0.3031])
# label tensor(0)
# p.data: tensor([0.8199, 0.1801])
# label tensor(0)
# p.data: tensor([0.7266, 0.2734])
# label tensor(0)
# p.data: tensor([0.4687, 0.5313])
# label tensor(0)
# p.data: tensor([0.9803, 0.0197])
# label tensor(0)
# p.data: tensor([0.9395, 0.0605])
# label tensor(0)
# p.data: tensor([0.9129, 0.0871])
# label tensor(0)
# p.data: tensor([0.9064, 0.0936])
# label tensor(0)
# p.data: tensor([0.9282, 0.0718])
# label tensor(0)
# p.data: tensor([0.8252, 0.1748])
# label tensor(0)
# p.data: tensor([0.9955, 0.0045])
# label tensor(0)
# p.data: tensor([0.9700, 0.0300])
# label tensor(0)
# p.data: tensor([0.0168, 0.9832])
# label tensor(0)
# p.data: tensor([0.7281, 0.2719])
# label tensor(0)
# p.data: tensor([0.7526, 0.2474])
# label tensor(0)
# p.data: tensor([0.6442, 0.3558])
# label tensor(0)
# p.data: tensor([0.6916, 0.3084])
# label tensor(0)
# p.data: tensor([0.8532, 0.1468])
# label tensor(0)
# p.data: tensor([0.7818, 0.2182])
# label tensor(0)
# p.data: tensor([0.4537, 0.5463])
# label tensor(0)
# p.data: tensor([0.9613, 0.0387])
# label tensor(0)
# p.data: tensor([0.6361, 0.3639])
# label tensor(0)
# p.data: tensor([0.9221, 0.0779])
# label tensor(0)
# p.data: tensor([0.5756, 0.4244])
# label tensor(0)
# p.data: tensor([0.3934, 0.6066])
# label tensor(0)
# p.data: tensor([0.4784, 0.5216])
# label tensor(0)
# p.data: tensor([0.7892, 0.2108])
# label tensor(0)
# p.data: tensor([0.9697, 0.0303])
# label tensor(0)
# p.data: tensor([0.5829, 0.4171])
# label tensor(0)
# p.data: tensor([0.9879, 0.0121])
# label tensor(0)
# p.data: tensor([0.3569, 0.6431])
# label tensor(0)
# p.data: tensor([0.7495, 0.2505])
# label tensor(0)
# p.data: tensor([0.7413, 0.2587])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.4033, 0.5967])
# label tensor(0)
# p.data: tensor([0.9710, 0.0290])
# label tensor(0)
# p.data: tensor([0.8571, 0.1429])
# label tensor(0)
# p.data: tensor([0.4043, 0.5957])
# label tensor(0)
# p.data: tensor([0.8416, 0.1584])
# label tensor(0)
# p.data: tensor([0.9959, 0.0041])
# label tensor(0)
# p.data: tensor([0.4911, 0.5089])
# label tensor(0)
# p.data: tensor([0.5402, 0.4598])
# label tensor(0)
# p.data: tensor([0.3125, 0.6875])
# label tensor(0)
# p.data: tensor([0.9529, 0.0471])
# label tensor(0)
# p.data: tensor([0.6168, 0.3832])
# label tensor(0)
# p.data: tensor([0.9175, 0.0825])
# label tensor(0)
# p.data: tensor([0.4716, 0.5284])
# label tensor(0)
# p.data: tensor([0.9396, 0.0604])
# label tensor(0)
# p.data: tensor([0.8971, 0.1029])
# label tensor(0)
# p.data: tensor([0.3651, 0.6349])
# label tensor(0)
# p.data: tensor([0.6376, 0.3624])
# label tensor(0)
# p.data: tensor([0.6742, 0.3258])
# label tensor(0)
# p.data: tensor([0.6418, 0.3582])
# label tensor(0)
# p.data: tensor([0.7356, 0.2644])
# label tensor(0)
# p.data: tensor([0.8414, 0.1586])
# label tensor(0)
# p.data: tensor([0.8809, 0.1191])
# label tensor(0)
# p.data: tensor([0.2600, 0.7400])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.4940, 0.5060])
# label tensor(0)
# p.data: tensor([0.9635, 0.0365])
# label tensor(0)
# p.data: tensor([0.1928, 0.8072])
# label tensor(0)
# p.data: tensor([0.8309, 0.1691])
# label tensor(0)
# p.data: tensor([0.4813, 0.5187])
# label tensor(0)
# p.data: tensor([0.8598, 0.1402])
# label tensor(0)
# p.data: tensor([0.4699, 0.5301])
# label tensor(0)
# p.data: tensor([0.7102, 0.2898])
# label tensor(0)
# p.data: tensor([0.6519, 0.3481])
# label tensor(0)
# p.data: tensor([0.6849, 0.3151])
# label tensor(0)
# p.data: tensor([0.4842, 0.5158])
# label tensor(0)
# p.data: tensor([0.3204, 0.6796])
# label tensor(0)
# p.data: tensor([9.9902e-01, 9.7803e-04])
# label tensor(0)
# p.data: tensor([0.8572, 0.1428])
# label tensor(0)
# p.data: tensor([0.5022, 0.4978])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.4575, 0.5425])
# label tensor(0)
# p.data: tensor([0.4220, 0.5780])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.8064, 0.1936])
# label tensor(0)
# p.data: tensor([0.3765, 0.6235])
# label tensor(0)
# p.data: tensor([0.7975, 0.2025])
# label tensor(0)
# p.data: tensor([0.7164, 0.2836])
# label tensor(0)
# p.data: tensor([0.6438, 0.3562])
# label tensor(0)
# p.data: tensor([0.8520, 0.1480])
# label tensor(0)
# p.data: tensor([0.9107, 0.0893])
# label tensor(0)
# p.data: tensor([0.2538, 0.7462])
# label tensor(0)
# p.data: tensor([0.7818, 0.2182])
# label tensor(0)
# p.data: tensor([0.7553, 0.2447])
# label tensor(0)
# p.data: tensor([0.0038, 0.9962])
# label tensor(0)
# p.data: tensor([0.4155, 0.5845])
# label tensor(0)
# p.data: tensor([0.8997, 0.1003])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.6081, 0.3919])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.5320, 0.4680])
# label tensor(0)
# p.data: tensor([0.7347, 0.2653])
# label tensor(0)
# p.data: tensor([0.5020, 0.4980])
# label tensor(0)
# p.data: tensor([0.7860, 0.2140])
# label tensor(0)
# p.data: tensor([0.7204, 0.2796])
# label tensor(0)
# p.data: tensor([0.8915, 0.1085])
# label tensor(0)
# p.data: tensor([0.5241, 0.4759])
# label tensor(0)
# p.data: tensor([0.4830, 0.5170])
# label tensor(0)
# p.data: tensor([0.9268, 0.0732])
# label tensor(0)
# p.data: tensor([0.5764, 0.4236])
# label tensor(0)
# p.data: tensor([0.6165, 0.3835])
# label tensor(0)
# p.data: tensor([0.4386, 0.5614])
# label tensor(0)
# p.data: tensor([0.6971, 0.3029])
# label tensor(0)
# p.data: tensor([0.3487, 0.6513])
# label tensor(0)
# p.data: tensor([0.9071, 0.0929])
# label tensor(0)
# p.data: tensor([0.4731, 0.5269])
# label tensor(0)
# p.data: tensor([0.6272, 0.3728])
# label tensor(0)
# p.data: tensor([0.5351, 0.4649])
# label tensor(0)
# p.data: tensor([0.2765, 0.7235])
# label tensor(0)
# p.data: tensor([0.9560, 0.0440])
# label tensor(0)
# p.data: tensor([0.9247, 0.0753])
# label tensor(0)
# p.data: tensor([0.6490, 0.3510])
# label tensor(0)
# p.data: tensor([0.6997, 0.3003])
# label tensor(0)
# p.data: tensor([0.7543, 0.2457])
# label tensor(0)
# p.data: tensor([0.5468, 0.4532])
# label tensor(0)
# p.data: tensor([0.7109, 0.2891])
# label tensor(0)
# p.data: tensor([0.6182, 0.3818])
# label tensor(0)
# p.data: tensor([0.8143, 0.1857])
# label tensor(0)
# p.data: tensor([0.7460, 0.2540])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.4945, 0.5055])
# label tensor(0)
# p.data: tensor([0.6375, 0.3625])
# label tensor(0)
# p.data: tensor([0.6989, 0.3011])
# label tensor(0)
# p.data: tensor([0.8394, 0.1606])
# label tensor(0)
# p.data: tensor([0.5963, 0.4037])
# label tensor(0)
# p.data: tensor([0.5440, 0.4560])
# label tensor(0)
# p.data: tensor([0.4847, 0.5153])
# label tensor(0)
# p.data: tensor([0.4792, 0.5208])
# label tensor(0)
# p.data: tensor([0.8906, 0.1094])
# label tensor(0)
# p.data: tensor([0.9684, 0.0316])
# label tensor(0)
# p.data: tensor([0.8359, 0.1641])
# label tensor(0)
# p.data: tensor([0.9403, 0.0597])
# label tensor(0)
# p.data: tensor([0.6568, 0.3432])
# label tensor(0)
# p.data: tensor([0.6985, 0.3015])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.4661, 0.5339])
# label tensor(0)
# p.data: tensor([0.8412, 0.1588])
# label tensor(0)
# p.data: tensor([0.9659, 0.0341])
# label tensor(0)
# p.data: tensor([0.4806, 0.5194])
# label tensor(0)
# p.data: tensor([0.8925, 0.1075])
# label tensor(0)
# p.data: tensor([0.8384, 0.1616])
# label tensor(0)
# p.data: tensor([0.4816, 0.5184])
# label tensor(0)
# p.data: tensor([0.7761, 0.2239])
# label tensor(0)
# p.data: tensor([0.3796, 0.6204])
# label tensor(0)
# p.data: tensor([0.2463, 0.7537])
# label tensor(0)
# p.data: tensor([0.8564, 0.1436])
# label tensor(0)
# p.data: tensor([0.6193, 0.3807])
# label tensor(0)
# p.data: tensor([0.9367, 0.0633])
# label tensor(0)
# p.data: tensor([0.9737, 0.0263])
# label tensor(0)
# p.data: tensor([0.5340, 0.4660])
# label tensor(0)
# p.data: tensor([0.0336, 0.9664])
# label tensor(0)
# p.data: tensor([0.9395, 0.0605])
# label tensor(0)
# p.data: tensor([0.4747, 0.5253])
# label tensor(0)
# p.data: tensor([0.7906, 0.2094])
# label tensor(0)
# p.data: tensor([0.3855, 0.6145])
# label tensor(0)
# p.data: tensor([0.7878, 0.2122])
# label tensor(0)
# p.data: tensor([0.6790, 0.3210])
# label tensor(0)
# p.data: tensor([9.9980e-01, 1.9965e-04])
# label tensor(0)
# p.data: tensor([0.9987, 0.0013])
# label tensor(0)
# p.data: tensor([0.4420, 0.5580])
# label tensor(0)
# p.data: tensor([0.7455, 0.2545])
# label tensor(0)
# p.data: tensor([0.9020, 0.0980])
# label tensor(0)
# p.data: tensor([0.8175, 0.1825])
# label tensor(0)
# p.data: tensor([0.7375, 0.2625])
# label tensor(0)
# p.data: tensor([0.9187, 0.0813])
# label tensor(0)
# p.data: tensor([0.7687, 0.2313])
# label tensor(0)
# p.data: tensor([0.8524, 0.1476])
# label tensor(0)
# p.data: tensor([0.8546, 0.1454])
# label tensor(0)
# p.data: tensor([0.9426, 0.0574])
# label tensor(0)
# p.data: tensor([0.8834, 0.1166])
# label tensor(0)
# p.data: tensor([0.4039, 0.5961])
# label tensor(0)
# p.data: tensor([0.7468, 0.2532])
# label tensor(0)
# p.data: tensor([0.7498, 0.2502])
# label tensor(0)
# p.data: tensor([9.9969e-01, 3.0678e-04])
# label tensor(0)
# p.data: tensor([0.6195, 0.3805])
# label tensor(0)
# p.data: tensor([0.5200, 0.4800])
# label tensor(0)
# p.data: tensor([0.9786, 0.0214])
# label tensor(0)
# p.data: tensor([0.7864, 0.2136])
# label tensor(0)
# p.data: tensor([0.7369, 0.2631])
# label tensor(0)
# p.data: tensor([0.7643, 0.2357])
# label tensor(0)
# p.data: tensor([0.7926, 0.2074])
# label tensor(0)
# p.data: tensor([0.3468, 0.6532])
# label tensor(0)
# p.data: tensor([0.3815, 0.6185])
# label tensor(0)
# p.data: tensor([0.6923, 0.3077])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.0507, 0.9493])
# label tensor(1)
# p.data: tensor([0.6308, 0.3692])
# label tensor(1)
# p.data: tensor([0.0504, 0.9496])
# label tensor(1)
# p.data: tensor([0.7043, 0.2957])
# label tensor(1)
# p.data: tensor([0.1878, 0.8122])
# label tensor(1)
# p.data: tensor([0.5304, 0.4696])
# label tensor(1)
# p.data: tensor([0.0625, 0.9375])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.5133, 0.4867])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.9462, 0.0538])
# label tensor(1)
# p.data: tensor([0.0411, 0.9589])
# label tensor(1)
# p.data: tensor([0.4507, 0.5493])
# label tensor(1)
# p.data: tensor([0.3622, 0.6378])
# label tensor(1)
# p.data: tensor([0.6077, 0.3923])
# label tensor(1)
# p.data: tensor([0.1833, 0.8167])
# label tensor(1)
# p.data: tensor([0.4838, 0.5162])
# label tensor(1)
# p.data: tensor([0.9259, 0.0741])
# label tensor(1)
# p.data: tensor([0.1294, 0.8706])
# label tensor(1)
# p.data: tensor([0.8303, 0.1697])
# label tensor(1)
# p.data: tensor([0.0910, 0.9090])
# label tensor(1)
# p.data: tensor([0.0655, 0.9345])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.3080, 0.6920])
# label tensor(1)
# p.data: tensor([0.3036, 0.6964])
# label tensor(1)
# p.data: tensor([0.0198, 0.9802])
# label tensor(1)
# p.data: tensor([0.4360, 0.5640])
# label tensor(1)
# p.data: tensor([0.0818, 0.9182])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.6103, 0.3897])
# label tensor(1)
# p.data: tensor([0.0141, 0.9859])
# label tensor(1)
# p.data: tensor([0.4082, 0.5918])
# label tensor(1)
# p.data: tensor([0.1999, 0.8001])
# label tensor(1)
# p.data: tensor([0.1279, 0.8721])
# label tensor(1)
# p.data: tensor([0.5933, 0.4067])
# label tensor(1)
# p.data: tensor([0.0913, 0.9087])
# label tensor(1)
# p.data: tensor([0.2004, 0.7996])
# label tensor(1)
# p.data: tensor([0.2184, 0.7816])
# label tensor(1)
# p.data: tensor([0.3505, 0.6495])
# label tensor(1)
# p.data: tensor([0.3218, 0.6782])
# label tensor(1)
# p.data: tensor([0.1131, 0.8869])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.6536, 0.3464])
# label tensor(1)
# p.data: tensor([0.4500, 0.5500])
# label tensor(1)
# p.data: tensor([0.3759, 0.6241])
# label tensor(1)
# p.data: tensor([0.5795, 0.4205])
# label tensor(1)
# p.data: tensor([0.4788, 0.5212])
# label tensor(1)
# p.data: tensor([0.5959, 0.4041])
# label tensor(1)
# p.data: tensor([0.5678, 0.4322])
# label tensor(1)
# p.data: tensor([0.7205, 0.2795])
# label tensor(1)
# p.data: tensor([0.3575, 0.6425])
# label tensor(1)
# p.data: tensor([0.5597, 0.4403])
# label tensor(1)
# p.data: tensor([0.9470, 0.0530])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.3447, 0.6553])
# label tensor(1)
# p.data: tensor([0.4701, 0.5299])
# label tensor(1)
# p.data: tensor([0.5370, 0.4630])
# label tensor(1)
# p.data: tensor([0.4770, 0.5230])
# label tensor(1)
# p.data: tensor([0.2606, 0.7394])
# label tensor(1)
# p.data: tensor([0.3357, 0.6643])
# label tensor(1)
# p.data: tensor([0.2015, 0.7985])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.7850, 0.2150])
# label tensor(1)
# p.data: tensor([0.5370, 0.4630])
# label tensor(1)
# p.data: tensor([0.3955, 0.6045])
# label tensor(1)
# p.data: tensor([0.2344, 0.7656])
# label tensor(1)
# p.data: tensor([0.3475, 0.6525])
# label tensor(1)
# p.data: tensor([0.4946, 0.5054])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.3453, 0.6547])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.4251, 0.5749])
# label tensor(1)
# p.data: tensor([0.0701, 0.9299])
# label tensor(1)
# p.data: tensor([0.6089, 0.3911])
# label tensor(1)
# p.data: tensor([0.6595, 0.3405])
# label tensor(1)
# p.data: tensor([0.5014, 0.4986])
# label tensor(1)
# p.data: tensor([0.1816, 0.8184])
# label tensor(1)
# p.data: tensor([0.5982, 0.4018])
# label tensor(1)
# p.data: tensor([0.2644, 0.7356])
# label tensor(1)
# p.data: tensor([0.3321, 0.6679])
# label tensor(1)
# p.data: tensor([0.2192, 0.7808])
# label tensor(1)
# p.data: tensor([0.0108, 0.9892])
# label tensor(1)
# p.data: tensor([0.7934, 0.2066])
# label tensor(1)
# p.data: tensor([0.5068, 0.4932])
# label tensor(1)
# p.data: tensor([0.5110, 0.4890])
# label tensor(1)
# p.data: tensor([0.0035, 0.9965])
# label tensor(1)
# p.data: tensor([0.4991, 0.5009])
# label tensor(1)
# p.data: tensor([0.3590, 0.6410])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.2926, 0.7074])
# label tensor(1)
# p.data: tensor([0.2321, 0.7679])
# label tensor(1)
# p.data: tensor([0.0777, 0.9223])
# label tensor(1)
# p.data: tensor([0.7520, 0.2480])
# label tensor(1)
# p.data: tensor([0.2179, 0.7821])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.2376, 0.7624])
# label tensor(1)
# p.data: tensor([0.0171, 0.9829])
# label tensor(1)
# p.data: tensor([0.5348, 0.4652])
# label tensor(1)
# p.data: tensor([0.6128, 0.3872])
# label tensor(1)
# p.data: tensor([0.5513, 0.4487])
# label tensor(1)
# p.data: tensor([0.0057, 0.9943])
# label tensor(1)
# p.data: tensor([0.2138, 0.7862])
# label tensor(1)
# p.data: tensor([0.1589, 0.8411])
# label tensor(1)
# p.data: tensor([0.0741, 0.9259])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.7692, 0.2308])
# label tensor(1)
# p.data: tensor([0.1784, 0.8216])
# label tensor(1)
# p.data: tensor([0.1721, 0.8279])
# label tensor(1)
# p.data: tensor([0.5378, 0.4622])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.1403, 0.8597])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.2823, 0.7177])
# label tensor(1)
# p.data: tensor([0.5154, 0.4846])
# label tensor(1)
# p.data: tensor([0.3424, 0.6576])
# label tensor(1)
# p.data: tensor([0.1814, 0.8186])
# label tensor(1)
# p.data: tensor([0.0137, 0.9863])
# label tensor(1)
# p.data: tensor([0.0232, 0.9768])
# label tensor(1)
# p.data: tensor([0.1869, 0.8131])
# label tensor(1)
# p.data: tensor([0.2720, 0.7280])
# label tensor(1)
# p.data: tensor([0.6473, 0.3527])
# label tensor(1)
# p.data: tensor([0.0248, 0.9752])
# label tensor(1)
# p.data: tensor([0.4618, 0.5382])
# label tensor(1)
# p.data: tensor([0.7927, 0.2073])
# label tensor(1)
# p.data: tensor([0.0341, 0.9659])
# label tensor(1)
# p.data: tensor([0.5262, 0.4738])
# label tensor(1)
# p.data: tensor([0.5378, 0.4622])
# label tensor(1)
# p.data: tensor([0.2423, 0.7577])
# label tensor(1)
# p.data: tensor([0.4745, 0.5255])
# label tensor(1)
# p.data: tensor([0.2262, 0.7738])
# label tensor(1)
# p.data: tensor([0.3133, 0.6867])
# label tensor(1)
# p.data: tensor([0.0200, 0.9800])
# label tensor(1)
# p.data: tensor([0.0458, 0.9542])
# label tensor(1)
# p.data: tensor([0.1510, 0.8490])
# label tensor(1)
# p.data: tensor([0.0598, 0.9402])
# label tensor(1)
# p.data: tensor([0.2940, 0.7060])
# label tensor(1)
# p.data: tensor([0.0721, 0.9279])
# label tensor(1)
# p.data: tensor([0.4350, 0.5650])
# label tensor(1)
# p.data: tensor([0.3718, 0.6282])
# label tensor(1)
# p.data: tensor([0.2267, 0.7733])
# label tensor(1)
# p.data: tensor([0.1244, 0.8756])
# label tensor(1)
# p.data: tensor([0.0562, 0.9438])
# label tensor(1)
# p.data: tensor([0.1626, 0.8374])
# label tensor(1)
# p.data: tensor([0.1798, 0.8202])
# label tensor(1)
# p.data: tensor([0.2518, 0.7482])
# label tensor(1)
# p.data: tensor([0.3953, 0.6047])
# label tensor(1)
# p.data: tensor([0.3803, 0.6197])
# label tensor(1)
# p.data: tensor([0.2712, 0.7288])
# label tensor(1)
# p.data: tensor([0.0383, 0.9617])
# label tensor(1)
# p.data: tensor([0.3407, 0.6593])
# label tensor(1)
# p.data: tensor([0.8317, 0.1683])
# label tensor(1)
# p.data: tensor([0.3094, 0.6906])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.4705, 0.5295])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.3136, 0.6864])
# label tensor(1)
# p.data: tensor([0.6379, 0.3621])
# label tensor(1)
# p.data: tensor([0.3068, 0.6932])
# label tensor(1)
# p.data: tensor([0.4661, 0.5339])
# label tensor(1)
# p.data: tensor([0.1352, 0.8648])
# label tensor(1)
# p.data: tensor([0.0036, 0.9964])
# label tensor(1)
# p.data: tensor([0.5165, 0.4835])
# label tensor(1)
# p.data: tensor([0.1129, 0.8871])
# label tensor(1)
# p.data: tensor([0.0040, 0.9960])
# label tensor(1)
# p.data: tensor([0.3020, 0.6980])
# label tensor(1)
# p.data: tensor([0.3156, 0.6844])
# label tensor(1)
# p.data: tensor([0.1552, 0.8448])
# label tensor(1)
# p.data: tensor([0.3524, 0.6476])
# label tensor(1)
# p.data: tensor([0.1474, 0.8526])
# label tensor(1)
# p.data: tensor([0.0745, 0.9255])
# label tensor(1)
# p.data: tensor([0.3782, 0.6218])
# label tensor(1)
# p.data: tensor([0.4899, 0.5101])
# label tensor(1)
# p.data: tensor([0.0701, 0.9299])
# label tensor(1)
# p.data: tensor([0.3896, 0.6104])
# label tensor(1)
# p.data: tensor([0.1644, 0.8356])
# label tensor(1)
# p.data: tensor([0.2129, 0.7871])
# label tensor(1)
# p.data: tensor([0.5074, 0.4926])
# label tensor(1)
# p.data: tensor([0.4881, 0.5119])
# label tensor(1)
# p.data: tensor([0.4092, 0.5908])
# label tensor(1)
# p.data: tensor([0.5884, 0.4116])
# label tensor(1)
# p.data: tensor([0.0473, 0.9527])
# label tensor(1)
# p.data: tensor([0.4440, 0.5560])
# label tensor(1)
# p.data: tensor([0.4954, 0.5046])
# label tensor(1)
# p.data: tensor([0.1457, 0.8543])
# label tensor(1)
# p.data: tensor([0.6893, 0.3107])
# label tensor(1)
# Test accuracy 97.66666667

# %%
# Function to get predictions for an image
# 0 = car is not damaged
# 1 = car is damaged

def predict(image):
      """
        Args:
            image: image to classify
        Returns:
            Image prediction as damaged or not damaged
        """
  with torch.no_grad():

    # Transforms image to grascale, 28 by 28 dimension and tensor
    img_as_tensor = transforms.Compose([transforms.Grayscale(num_output_channels=1),transforms.Resize([28,28]) ,transforms.ToTensor()])(image)

    # Sets batch number for pytorch conv layer to none
    img_as_tensor = img_as_tensor[None]

    # Pass image tensor to model
    pred = model(img_as_tensor)
    # Get the prediction for the image
    pred = torch.nn.functional.softmax(pred, dim=1)
    prediction = np.argmax(pred, axis=1)

    # Return prediction class
    return prediction.item()
# Out:
# tensor([[0.6225, 0.3775]])
# 0

# %%
#Saving the CNN architecture in a file
torch.save(model.state_dict(), 'model.pt')
print("Model Saved")
# Out:
# Model Saved
